# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x11a2fb250>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist] # 이름만 출력
# Out:
# ['DejaVu Sans Mono',
#  'cmss10',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeOneSym',
#  'cmex10',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'cmtt10',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'cmr10',
#  'cmb10',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STFangsong',
#  'Hiragino Mincho ProN',
#  'Noto Sans Rejang',
#  'STIXIntegralsUpSm',
#  'Noto Sans Old Turkic',
#  'Diwan Kufi',
#  'Apple LiSung',
#  'Noto Sans Kaithi',
#  'Yuppy TC',
#  'Arial Narrow',
#  'Waseem',
#  'PCMyungjo',
#  'Noto Sans Duployan',
#  'Oriya Sangam MN',
#  'Bodoni 72',
#  'Noto Sans PhagsPa',
#  'Noto Sans Multani',
#  'Noto Sans Ugaritic',
#  'Baghdad',
#  'Noto Sans Hanunoo',
#  'Gurmukhi MT',
#  'Kannada MN',
#  'Noto Sans Tai Viet',
#  'Tamil MN',
#  'Chalkboard SE',
#  'Al Bayan',
#  'Noto Sans Marchen',
#  'STIXIntegralsUp',
#  '.SF Arabic',
#  'Copperplate',
#  'STIXVariants',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'Wawati TC',
#  'Noto Sans Cypriot',
#  'Apple Braille',
#  'Snell Roundhand',
#  'Apple Braille',
#  'Noto Sans Tai Tham',
#  'Big Caslon',
#  'STIXNonUnicode',
#  'Devanagari MT',
#  'Noto Sans Gunjala Gondi',
#  'Hiragino Sans',
#  'Noto Sans Brahmi',
#  'Zapf Dingbats',
#  'Diwan Thuluth',
#  'Cochin',
#  'STIX Two Math',
#  'SimSong',
#  'Noto Sans Meetei Mayek',
#  'KufiStandardGK',
#  '.SF NS Mono',
#  'Yuppy SC',
#  'System Font',
#  'LingWai SC',
#  'Hiragino Sans',
#  'PT Serif',
#  'Noto Serif Balinese',
#  'Courier',
#  'Apple Chancery',
#  'Bangla Sangam MN',
#  'Apple SD Gothic Neo',
#  'Noto Sans Modi',
#  'Noto Serif Yezidi',
#  'Didot',
#  'Noto Sans Kayah Li',
#  'Georgia',
#  'BiauKaiHK',
#  '.ThonburiUI',
#  'Times New Roman',
#  'Farah',
#  'Noto Sans Old North Arabian',
#  'Osaka',
#  'Galvji',
#  'Muna',
#  'Hiragino Sans',
#  'Noto Sans Nabataean',
#  'STIXIntegralsUpD',
#  'Verdana',
#  'Baskerville',
#  'Toppan Bunkyu Gothic',
#  'Noto Sans Sharada',
#  '.SF Soft Numeric',
#  'Geneva',
#  'Wingdings 3',
#  'American Typewriter',
#  'Noto Sans Lycian',
#  'Noto Sans Pahawh Hmong',
#  'Noto Sans Psalter Pahlavi',
#  'Gujarati MT',
#  'Malayalam MN',
#  'Hiragino Sans',
#  'Noto Sans Bassa Vah',
#  'Kai',
#  'AppleGothic',
#  'Lantinghei SC',
#  'Mshtakan',
#  'Xingkai SC',
#  'Luminari',
#  '.SF Arabic Rounded',
#  'STIXIntegralsD',
#  'BM Kirang Haerang',
#  '.Keyboard',
#  'Noto Sans Old Italic',
#  'STIXSizeFiveSym',
#  'Noto Sans Samaritan',
#  'Noto Sans Cuneiform',
#  'Hiragino Sans',
#  'STIXIntegralsSm',
#  'STIXSizeThreeSym',
#  'STHeiti',
#  'Courier New',
#  'Fira Code',
#  '.DecoType Nastaleeq Urdu UI',
#  'Kokonor',
#  'Times New Roman',
#  'Al Tarikh',
#  'Lucida Grande',
#  'InaiMathi',
#  'GungSeo',
#  '.SF Compact Rounded',
#  'Kaiti SC',
#  'Apple Braille',
#  'Kohinoor Telugu',
#  'Mishafi',
#  'Futura',
#  'Noto Sans Meroitic',
#  '.SF NS Mono',
#  'Georgia',
#  'Libian SC',
#  'Impact',
#  'Phosphate',
#  'Noto Nastaliq Urdu',
#  'Noteworthy',
#  'PT Mono',
#  'Chalkduster',
#  'Party LET',
#  'Noto Sans Glagolitic',
#  'Noto Sans Khojki',
#  'Corsiva Hebrew',
#  'Courier New',
#  '.SF Compact',
#  'STHeiti',
#  '.CJK Symbols Fallback HK',
#  'Savoye LET',
#  'Lao Sangam MN',
#  'STIX Two Text',
#  'ITF Devanagari',
#  'Noto Sans Javanese',
#  'Trebuchet MS',
#  'Nanum Brush Script',
#  'Mukta Mahee',
#  'Apple Braille',
#  'Noto Sans Wancho',
#  'Marker Felt',
#  'HanziPen SC',
#  'Noto Sans Miao',
#  'Times New Roman',
#  'Oriya MN',
#  'Comic Sans MS',
#  'Fira Code',
#  'Microsoft Sans Serif',
#  'Sana',
#  'STIXNonUnicode',
#  'Hiragino Sans CNS',
#  'Noto Sans Adlam',
#  'STIXSizeOneSym',
#  'Trebuchet MS',
#  'Arial Unicode MS',
#  'Fira Code',
#  'Noto Sans Avestan',
#  'Arial Narrow',
#  'Sinhala MN',
#  'Apple LiGothic',
#  'Sathu',
#  'Noto Sans Elbasan',
#  'Hannotate SC',
#  'Noto Sans Vai',
#  'Kohinoor Bangla',
#  'Noto Sans Tirhuta',
#  'Krungthep',
#  'STIXIntegralsUp',
#  'Skia',
#  'Farisi',
#  'DIN Alternate',
#  'Noto Sans Imperial Aramaic',
#  '.Aqua Kana',
#  'Avenir',
#  'Kefa',
#  'Symbol',
#  'Noto Sans Mro',
#  'STIXGeneral',
#  'Noto Sans Manichaean',
#  'Telugu MN',
#  'Noto Sans Armenian',
#  'Baoli SC',
#  'Arial',
#  'STIXNonUnicode',
#  'Arial Hebrew',
#  'Verdana',
#  'Silom',
#  'Khmer Sangam MN',
#  'Courier New',
#  'STIXIntegralsUpD',
#  'STIXGeneral',
#  'Verdana',
#  '.New York',
#  'Raanana',
#  'Helvetica Neue',
#  'Palatino',
#  'Al Nile',
#  'Bangla MN',
#  '.SF Armenian',
#  'Hiragino Sans',
#  'Noto Sans Linear B',
#  'Kannada Sangam MN',
#  'Noto Sans Kharoshthi',
#  '.SF Georgian',
#  'Noto Sans Masaram Gondi',
#  'Noto Sans Inscriptional Pahlavi',
#  'Athelas',
#  'Gurmukhi MN',
#  'Noto Sans New Tai Lue',
#  '.SF NS Rounded',
#  'LiSong Pro',
#  'DecoType Naskh',
#  'Tahoma',
#  'Lao MN',
#  'Noto Sans Batak',
#  'Iowan Old Style',
#  'Noto Sans Sundanese',
#  'BM Hanna Air',
#  'Arial Unicode MS',
#  'Ayuthaya',
#  'Noto Sans Buhid',
#  'System Font',
#  'Hiragino Sans GB',
#  'Arial Rounded MT Bold',
#  'Toppan Bunkyu Midashi Gothic',
#  'STIXIntegralsSm',
#  'Superclarendon',
#  'Heiti TC',
#  'Osaka',
#  'Noto Sans Mongolian',
#  'Hiragino Sans',
#  'LiHei Pro',
#  'BM Hanna Pro',
#  'Noto Serif Hmong Nyiakeng',
#  'YuKyokasho Yoko',
#  'Trebuchet MS',
#  'Noto Sans Bamum',
#  'Marion',
#  'Noto Sans Coptic',
#  'Hiragino Sans',
#  'Apple Braille',
#  'Telugu Sangam MN',
#  'Georgia',
#  'Fira Code',
#  'Mishafi Gold',
#  'Noto Sans Newa',
#  'Trattatello',
#  'Arial Black',
#  'Noto Sans Chakma',
#  'Helvetica',
#  'Tsukushi A Round Gothic',
#  'Gurmukhi Sangam MN',
#  'STIXGeneral',
#  'Sinhala Sangam MN',
#  'STIXVariants',
#  'Bodoni Ornaments',
#  'Noto Sans Tifinagh',
#  'Zapfino',
#  'Songti SC',
#  'Noto Sans Saurashtra',
#  'Hiragino Maru Gothic Pro',
#  'YuGothic',
#  'Monaco',
#  'Noto Sans Osmanya',
#  'Tamil Sangam MN',
#  'Hiragino Sans',
#  'Noto Sans Old Persian',
#  'Noto Sans Tai Le',
#  'Shree Devanagari 714',
#  'Noto Sans Warang Citi',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Kannada',
#  '.SF Camera',
#  'Noto Sans Siddham',
#  'Academy Engraved LET',
#  'Damascus',
#  'Toppan Bunkyu Midashi Mincho',
#  'Noto Sans Ol Chiki',
#  'Thonburi',
#  'PT Serif Caption',
#  'Tsukushi B Round Gothic',
#  'STIXGeneral',
#  'Noto Sans Syloti Nagri',
#  'BM Dohyeon',
#  'Geeza Pro',
#  'Noto Sans Syriac',
#  'Beirut',
#  'Trebuchet MS',
#  'Georgia',
#  'Noto Sans Hanifi Rohingya',
#  'BM Yeonsung',
#  'PSL Ornanong Pro',
#  'Kailasa',
#  'Bradley Hand',
#  'Noto Sans Osage',
#  'Noto Sans Inscriptional Parthian',
#  'Noto Serif Ahom',
#  'Noto Serif Myanmar',
#  'Kohinoor Gujarati',
#  'Apple Symbols',
#  'Gujarati Sangam MN',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Avenir Next',
#  'Nadeem',
#  '.SF Georgian Rounded',
#  '.New York',
#  'Noto Sans Hatran',
#  'Noto Sans Linear A',
#  'Times New Roman',
#  'STIXNonUnicode',
#  'Andale Mono',
#  'Menlo',
#  'Papyrus',
#  'STIXSizeTwoSym',
#  'Times',
#  'Tahoma',
#  'Noto Sans Lepcha',
#  'Noto Sans Buginese',
#  'Fira Code',
#  'Wawati SC',
#  'Nanum Gothic',
#  'Nanum Myeongjo',
#  'PingFang HK',
#  'Kohinoor Devanagari',
#  'Myanmar MN',
#  'STIXIntegralsD',
#  'STIXSizeThreeSym',
#  '.SF Armenian Rounded',
#  'Arial',
#  'Comic Sans MS',
#  'STIX Two Text',
#  'Malayalam Sangam MN',
#  'Seravek',
#  'Noto Sans Tagalog',
#  'Wingdings 2',
#  'Noto Sans Old Permic',
#  'LingWai TC',
#  'Plantagenet Cherokee',
#  'STIXIntegralsUpSm',
#  'Bodoni 72 Smallcaps',
#  'Chalkboard',
#  'YuGothic',
#  'Webdings',
#  'BIZ UDGothic',
#  'Verdana',
#  'Noto Sans Khudawadi',
#  'Noto Sans Palmyrene',
#  'Noto Sans Gothic',
#  'Noto Sans Limbu',
#  'Noto Sans Bhaiksuki',
#  'Herculanum',
#  'Arial Narrow',
#  'Noto Sans Lydian',
#  'Klee',
#  'Arial',
#  'Noto Sans Phoenician',
#  'Arial',
#  'Noto Sans NKo',
#  'SignPainter',
#  'AppleMyungjo',
#  'Avenir Next Condensed',
#  'Noto Sans Takri',
#  '.SF Compact',
#  'Noto Sans Myanmar',
#  'Heiti TC',
#  'BIZ UDMincho',
#  'Rockwell',
#  'Wingdings',
#  'Fira Code',
#  'Devanagari Sangam MN',
#  'Noto Sans Sora Sompeng',
#  'Sukhumvit Set',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Mahajani',
#  'Hiragino Sans',
#  'Charter',
#  'BM Jua',
#  '.SF Hebrew',
#  'Noto Sans Cham',
#  'Fira Code',
#  '.SF Hebrew Rounded',
#  'Noto Sans Mandaic',
#  'STIXSizeOneSym',
#  'Euphemia UCAS',
#  'HeadLineA',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Yi',
#  'PT Sans',
#  'Hoefler Text',
#  'Noto Sans Canadian Aboriginal',
#  'Courier New',
#  'Myanmar Sangam MN',
#  'DIN Condensed',
#  'Gill Sans',
#  'STIXSizeFourSym',
#  'Noto Sans Lisu',
#  'Toppan Bunkyu Mincho',
#  'Noto Sans Mende Kikakui',
#  'Brush Script MT',
#  'BM Hanna 11yrs Old',
#  'New Peninim MT',
#  'Noto Sans Oriya',
#  'Yuanti SC',
#  'YuMincho',
#  'Bodoni 72 Oldstyle',
#  'Optima',
#  'PilGi',
#  'Hei',
#  'Arial Narrow',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans Carian',
#  'Noto Sans Thaana',
#  'Khmer MN',
#  'Hoefler Text']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
